# %% [markdown]
# # Statistical Test

# %%
#Reading Libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
#Reading Data
path = "./Data/Spotify_1921_to_2020.csv"
df_raw = pd.read_csv(path)

# %%
#scaling
scale_cols = ['duration_ms', 'key', 'loudness', 'popularity', 'tempo']
for col in scale_cols:
    maxVal = df_raw[col].abs().max()
    df_raw[col] = df_raw[col]/maxVal

#add weighting features1 based on statistical test on relationship with popularity
'''
weight_cols = ['energy', 'danceability', 'speechiness']
w_rate = 3
for col in weight_cols:
    df_raw[col] = w_rate*df_raw[col]

#add weighting features2
weight_cols = ['loudness', 'speechiness']
weight_cols = ['loudness']
w_rate = 1.5
for col in weight_cols:
    df_raw[col] = w_rate*df_raw[col]
'''
print(df_raw.select_dtypes(include = np.number).abs().max())
# Out:
# acousticness           0.996
# danceability           0.988
# duration_ms            1.000
# energy                 1.000
# explicit               1.000
# instrumentalness       1.000
# key                    1.000
# liveness               1.000
# loudness               1.000
# mode                   1.000
# popularity             1.000
# speechiness            0.969
# tempo                  1.000
# valence                1.000
# year                2020.000
# dtype: float64

# %%
#data preprocessing
def preprocessing(df, topN=20, startYear=1955):
    #use data from 1955
    df = df[df['year']>=startYear]
    df = df.select_dtypes(include = np.number)
    df = df.groupby('year').apply(lambda x: x.nlargest(topN, ['popularity']))
    df.drop(['year'], axis = 1, inplace = True)
    df = df.groupby('year').agg(['mean'])
    df.columns = [col[0] for col in df.columns.values]
    df.reset_index(inplace = True)
    return df

# %%
#set parameter
topN = 100
startYear = 1990
targetYear = 2016

#preprocess data
df = preprocessing(df_raw, topN=topN, startYear=startYear)
print(df.head())
print(df.columns)
# Out:
#    year  acousticness  danceability  duration_ms    energy  explicit  \
# 0  1990      0.206522       0.54928     0.049620  0.666730      0.05
# 1  1991      0.222771       0.55346     0.050100  0.628230      0.06
# 2  1992      0.251523       0.59920     0.047129  0.624950      0.15
# 3  1993      0.192939       0.60352     0.046679  0.625160      0.14
# 4  1994      0.225749       0.56453     0.046071  0.630753      0.16
#
#    instrumentalness       key  liveness  loudness  mode  popularity  \
# 0          0.052565  0.445455  0.171580 -0.146606  0.78      0.6378
# 1          0.032905  0.538182  0.182937 -0.159454  0.67      0.6632
# 2          0.018784  0.453636  0.182672 -0.147418  0.76      0.6549
# 3          0.070677  0.512727  0.174003 -0.161816  0.72      0.6638
# 4          0.037245  0.526364  0.185944 -0.146506  0.68      0.6708
#
#    speechiness     tempo   valence
# 0     0.058954  0.501952  0.521157
# 1     0.050675  0.484472  0.539474
# 2     0.072896  0.487823  0.589530
# 3     0.076079  0.494591  0.549954
# 4     0.077107  0.479310  0.572875
# Index(['year', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'popularity', 'speechiness', 'tempo', 'valence'],
#       dtype='object')

# %%
#add new feature for time-series regression
def add_n_years(df, startYear):
    df['n_years'] = df['year'] - startYear
    return df

#train-test data preparation
def get_train(df, targetYear = 2020):
    return df[df['year']<targetYear]

def get_test(df, targetYear = 2020, cols = []):    
    return df[df_raw['year'] == targetYear][cols]

# %%
#add new feature : # of years from 1921
df = add_n_years(df, startYear)
df_raw = add_n_years(df_raw, startYear)

#get train, test data
train = get_train(df)
cols = train.columns
test = get_test(df_raw, targetYear = targetYear, cols = train.columns)

# %%
def stat_test_lm(df, cols):
    for i, col in enumerate(cols):
        x = df['n_years'].values.reshape(-1, 1)
        y = df[col].values
        x = sm.add_constant(x)
        model = sm.OLS(y, x)
        results = model.fit()
        print(f'<{i+1}. {col}>')
        print(results.summary(), '\n\n')

# %%
#apply sub_model to all features
cols = ['acousticness', 'danceability', 'duration_ms', 'energy',
       'explicit', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'popularity', 'speechiness', 'tempo', 'valence']
drop_cols = ['explicit', 'key', 'mode', 'popularity'] 
#remove columns in drop_cols
cols = [col for col in cols if col not in drop_cols]

#Statistical Test on Linear Regression models
stat_test_lm(train, cols = cols)
# Out:
# <1. acousticness>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.114
# Method:                 Least Squares   F-statistic:                     4.714
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):             0.0386
# Time:                        17:54:19   Log-Likelihood:                 57.654
# No. Observations:                  30   AIC:                            -111.3
# Df Residuals:                      28   BIC:                            -108.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1856      0.013     14.215      0.000       0.159       0.212
# x1             0.0017      0.001      2.171      0.039    9.49e-05       0.003
# ==============================================================================
# Omnibus:                        2.017   Durbin-Watson:                   0.756
# Prob(Omnibus):                  0.365   Jarque-Bera (JB):                1.157
# Skew:                           0.078   Prob(JB):                        0.561
# Kurtosis:                       2.050   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <2. danceability>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     27.88
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):           1.29e-05
# Time:                        17:54:19   Log-Likelihood:                 69.683
# No. Observations:                  30   AIC:                            -135.4
# Df Residuals:                      28   BIC:                            -132.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5797      0.009     66.306      0.000       0.562       0.598
# x1             0.0027      0.001      5.280      0.000       0.002       0.004
# ==============================================================================
# Omnibus:                        1.544   Durbin-Watson:                   1.007
# Prob(Omnibus):                  0.462   Jarque-Bera (JB):                1.436
# Skew:                           0.471   Prob(JB):                        0.488
# Kurtosis:                       2.488   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <3. duration_ms>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.697
# Model:                            OLS   Adj. R-squared:                  0.686
# Method:                 Least Squares   F-statistic:                     64.26
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):           9.93e-09
# Time:                        17:54:19   Log-Likelihood:                 147.62
# No. Observations:                  30   AIC:                            -291.2
# Df Residuals:                      28   BIC:                            -288.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0487      0.001     74.886      0.000       0.047       0.050
# x1            -0.0003   3.85e-05     -8.016      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                        0.009   Durbin-Watson:                   0.728
# Prob(Omnibus):                  0.996   Jarque-Bera (JB):                0.099
# Skew:                          -0.006   Prob(JB):                        0.952
# Kurtosis:                       2.719   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <4. energy>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.8673
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):              0.360
# Time:                        17:54:19   Log-Likelihood:                 49.839
# No. Observations:                  30   AIC:                            -95.68
# Df Residuals:                      28   BIC:                            -92.88
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6780      0.017     40.019      0.000       0.643       0.713
# x1            -0.0009      0.001     -0.931      0.360      -0.003       0.001
# ==============================================================================
# Omnibus:                       13.280   Durbin-Watson:                   0.211
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                2.620
# Skew:                          -0.004   Prob(JB):                        0.270
# Kurtosis:                       1.552   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <5. instrumentalness>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.184
# Method:                 Least Squares   F-statistic:                     7.547
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):             0.0104
# Time:                        17:54:19   Log-Likelihood:                 83.411
# No. Observations:                  30   AIC:                            -162.8
# Df Residuals:                      28   BIC:                            -160.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0441      0.006      7.978      0.000       0.033       0.055
# x1            -0.0009      0.000     -2.747      0.010      -0.002      -0.000
# ==============================================================================
# Omnibus:                        1.151   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.562   Jarque-Bera (JB):                0.874
# Skew:                           0.039   Prob(JB):                        0.646
# Kurtosis:                       2.168   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <6. liveness>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                    0.4929
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):              0.488
# Time:                        17:54:19   Log-Likelihood:                 82.583
# No. Observations:                  30   AIC:                            -161.2
# Df Residuals:                      28   BIC:                            -158.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1862      0.006     32.737      0.000       0.175       0.198
# x1            -0.0002      0.000     -0.702      0.488      -0.001       0.000
# ==============================================================================
# Omnibus:                        0.749   Durbin-Watson:                   1.422
# Prob(Omnibus):                  0.688   Jarque-Bera (JB):                0.717
# Skew:                          -0.054   Prob(JB):                        0.699
# Kurtosis:                       2.250   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <7. loudness>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.451
# Model:                            OLS   Adj. R-squared:                  0.431
# Method:                 Least Squares   F-statistic:                     22.98
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):           4.88e-05
# Time:                        17:54:19   Log-Likelihood:                 84.431
# No. Observations:                  30   AIC:                            -164.9
# Df Residuals:                      28   BIC:                            -162.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1386      0.005    -25.924      0.000      -0.150      -0.128
# x1             0.0015      0.000      4.793      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                        4.415   Durbin-Watson:                   0.332
# Prob(Omnibus):                  0.110   Jarque-Bera (JB):                1.784
# Skew:                          -0.189   Prob(JB):                        0.410
# Kurtosis:                       1.867   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <8. speechiness>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.456
# Method:                 Least Squares   F-statistic:                     25.33
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):           2.53e-05
# Time:                        17:54:19   Log-Likelihood:                 95.393
# No. Observations:                  30   AIC:                            -186.8
# Df Residuals:                      28   BIC:                            -184.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0676      0.004     18.205      0.000       0.060       0.075
# x1             0.0011      0.000      5.033      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                        2.190   Durbin-Watson:                   1.430
# Prob(Omnibus):                  0.334   Jarque-Bera (JB):                1.233
# Skew:                          -0.124   Prob(JB):                        0.540
# Kurtosis:                       2.038   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <9. tempo>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.036
# Method:                 Least Squares   F-statistic:                  0.002308
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):              0.962
# Time:                        17:54:19   Log-Likelihood:                 83.378
# No. Observations:                  30   AIC:                            -162.8
# Df Residuals:                      28   BIC:                            -160.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4909      0.006     88.634      0.000       0.480       0.502
# x1         -1.576e-05      0.000     -0.048      0.962      -0.001       0.001
# ==============================================================================
# Omnibus:                        0.083   Durbin-Watson:                   1.326
# Prob(Omnibus):                  0.959   Jarque-Bera (JB):                0.054
# Skew:                           0.053   Prob(JB):                        0.973
# Kurtosis:                       2.820   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# <10. valence>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.494
# Model:                            OLS   Adj. R-squared:                  0.476
# Method:                 Least Squares   F-statistic:                     27.32
# Date:                Mon, 30 Jan 2023   Prob (F-statistic):           1.49e-05
# Time:                        17:54:19   Log-Likelihood:                 55.917
# No. Observations:                  30   AIC:                            -107.8
# Df Residuals:                      28   BIC:                            -105.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6004      0.014     43.399      0.000       0.572       0.629
# x1            -0.0043      0.001     -5.227      0.000      -0.006      -0.003
# ==============================================================================
# Omnibus:                        2.023   Durbin-Watson:                   1.013
# Prob(Omnibus):                  0.364   Jarque-Bera (JB):                1.829
# Skew:                          -0.526   Prob(JB):                        0.401
# Kurtosis:                       2.405   Cond. No.                         33.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The above statistical test shows that 'danceability', 'duration_ms', 'instrumentalness', 'loudness', 'speechiness', and 'valence' have some linear relationship with time. Moreover, in terms of 'duration_ms', according to the value of R-squared, 69.7% of the variation is explained by time.
